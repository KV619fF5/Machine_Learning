# %%
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
x = np.random.randint(1,200,1000)
y = np.random.randint(1,200,1000)

# %%
import numpy as np

slp= 0
intcpt = 0

learn = 0.00001

iterations = 1000000

for i in range(iterations):
    y_pred = intcpt + slp*x
    intcpt -= learn*2*(y_pred - y).mean()
    slp -= learn*2*(x*(y_pred - y)).mean()
    
print(intcpt,slp)
# Out:
# 96.93419882520391 0.01630535559771897

# %%
x.shape
# Out:
# (1000,)

# %%
plt.scatter( x, y, color = 'green' )
y_pred = intercept + slope*x
plt.plot( x,y_pred , color = 'yellow')

# %% [markdown]
# # USING SKLEARN

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

x=x.reshape((len(x),1))
y=y.reshape((len(x),1))
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20)
regr=LinearRegression()
regr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
regr.coef_
# Out:
# array([[-0.01321949]])

# %%
regr.intercept_
# Out:
# array([98.58151011])

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# For Gradient Descent
# Slope =96.93419882520391
# Intercept = 0.01630535559771897
#
#
# For SKLEARN
#
# Slope = -0.01321949
# Intercept = 98.58151011
